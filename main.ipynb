# %% [markdown]
# ## Intro

# %%
import lib.datasets as ds

# %%
t = ds.Tourism()
t.plot()
t.train.shape
# Out:
# (149, 1)

# %%
c = ds.COVID()
c.plot()

# %%
btc = ds.Bitcoin()
btc.plot()

# %%
ped = ds.Pedestrian()
ped.plot()
ped.train.shape
# Out:
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/datasets.py:244: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series = series.groupby(hourly_bins, axis=0).mean().round(3)
# (2811, 1)

# %%
e = ds.EnergyConsumption()
e.plot()
# Out:
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/datasets.py:203: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   hourly_bins = datetime_indices.floor("H")
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/datasets.py:204: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   df = df.groupby(hourly_bins, axis=0).mean().round(3)

# %%
web = ds.Web()
web.plot()

# %%
air = ds.AirQuality()
air.plot()
air.train.shape
# Out:
# (7400, 1)

# %%
birth = ds.USBirths()
birth.plot()
birth.train.shape
# Out:
# (5844, 1)
