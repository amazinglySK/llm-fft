# %%
# %load_ext autoreload
# %autoreload 2

# %%
import lib.new_datasets as ds
import numpy as np
from exp import LlagLlamaExperiment

# %% [markdown]
# ## List of datasets
#
# 1. AirQuality
# 2. US Births
# 3. Bitcoin price
# 4. COVID Deaths
# 5. Energy Consumption
# 6. Air Passengers
# 7. Pedestrians
# 8. Tourism
# 9. Traffic
# 10. Web traffic

# %%
exp = LlagLlamaExperiment()
tourism = ds.Tourism()
forecasts, filtered_forecasts, tss = exp(
    tourism, 40, prediction_length=6, context_length=12 * 6
)
raw_metrics, filtered_metrics = exp.evaluate(forecasts, filtered_forecasts, tss)
# Out:
#                values  id
# 1979-01-01  1149.8700  T1
# 1979-02-01  1053.8002  T1
# 1979-03-01  1388.8798  T1
# 1979-04-01  1783.3702  T1
# 1979-05-01  1921.0252  T1
# 6
# Beginning prediction on raw time series
# Finished prediction on raw time series
# Filtering signals
# Beginning prediction on filtered time series
# Finished prediction on filtered time series
# Running evaluation: 9it [00:00, 220.74it/s]
# Running evaluation: 9it [00:00, 249.11it/s]

# %%
exp.plot_results(forecasts, tss, "./results/experiments/tourism_raw_forecast.png")
exp.plot_results(
    filtered_forecasts, tss, "./results/experiments/tourism_filtered_forecasts.png"
)
exp.plot_together(
    forecasts,
    filtered_forecasts,
    "./results/experiments/tourism_filtered_raw_comparison.png",
)

print("CRPS (raw):", raw_metrics["mean_wQuantileLoss"])
print("RMSE (raw):", np.sqrt(raw_metrics["MSE"]))
print("CRPS (filtered):", filtered_metrics["mean_wQuantileLoss"])
print("RMSE (filtered):", np.sqrt(filtered_metrics["MSE"]))
# Out:
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/exp.py:250: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# CRPS (raw): 0.13564214596224106
# RMSE (raw): 241.5474032223742
# CRPS (filtered): 0.15623884108170918
# RMSE (filtered): 253.7845969960622

# %%
ped = ds.Pedestrian()
forecasts, filtered_forecasts, tss = exp(
    ped, 400, prediction_length=6, context_length=12 * 6
)
raw_metrics, filtered_metrics = exp.evaluate(forecasts, filtered_forecasts, tss)
# Out:
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/lib/new_datasets.py:228: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   series_values_df.groupby(hourly_bins, axis=0).mean().round(3)
#               values  id
# 2009-05-01  1536.208  T1
# 2009-05-02  1250.125  T1
# 2009-05-03   930.292  T1
# 2009-05-04  1103.375  T1
# 2009-05-05  1111.292  T1
# 6
# Beginning prediction on raw time series
# Finished prediction on raw time series
# Filtering signals
# Beginning prediction on filtered time series
# Finished prediction on filtered time series
# Running evaluation: 9it [00:00, 236.29it/s]
# Running evaluation: 9it [00:00, 254.19it/s]

# %%
exp.plot_results(forecasts, tss, "./results/experiments/pedestrian_raw_forecast.png")
exp.plot_results(
    filtered_forecasts, tss, "./results/experiments/pedestrian_filtered_forecasts.png"
)
exp.plot_together(
    forecasts,
    filtered_forecasts,
    "./results/experiments/pedestrian_filtered_raw_comparison.png",
)

print("CRPS (raw):", raw_metrics["mean_wQuantileLoss"])
print("RMSE (raw):", np.sqrt(raw_metrics["MSE"]))
print("CRPS (filtered):", filtered_metrics["mean_wQuantileLoss"])
print("RMSE (filtered):", np.sqrt(filtered_metrics["MSE"]))
# Out:
# /Users/shashwatkrishna/Desktop/Programming/llm-fft/exp.py:250: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# CRPS (raw): 0.13679972179434363
# RMSE (raw): 247.42721759996263
# CRPS (filtered): 0.14002883456806525
# RMSE (filtered): 227.19055437284013

# %%
exp.plot_results(forecasts, tss, "./results/experiments/pedestrian_raw_forecast.png")
exp.plot_results(
    filtered_forecasts, tss, "./results/experiments/pedestrian_filtered_forecasts.png"
)
exp.plot_together(
    forecasts,
    filtered_forecasts,
    "./results/experiments/pedestrian_filtered_raw_comparison.png",
)

print("CRPS (raw):", raw_metrics["mean_wQuantileLoss"])
print("RMSE (raw):", np.sqrt(raw_metrics["MSE"]))
print("CRPS (filtered):", filtered_metrics["mean_wQuantileLoss"])
print("RMSE (filtered):", np.sqrt(filtered_metrics["MSE"]))
